# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
carrier = cv.imread('carrier.jpg')
msg = cv.imread('message.png')

# %%
np.shape(carrier)
# Out:
# (1067, 1080, 3)

# %%
carrier = carrier[:,:1067,:]
np.shape(carrier)
# Out:
# (1067, 1067, 3)

# %%
plt.imshow(carrier)

# %%
plt.imshow(msg)

# %%
np.shape(msg)
# Out:
# (1616, 2874, 3)

# %%
final = np.zeros([500*1616, 500*2874, 3])

# %%
c = cv.resize(carrier, (500, 500)) 
plt.imshow(c)

# %%
500*1616 * 500*2874
# Out:
# 1161096000000

# %%
for i in range(1616):
  for j in range(2874):
    final[i*500:i*500+500, j*500: j*500+500, :] = c
